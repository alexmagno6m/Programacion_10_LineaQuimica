# %% [markdown]
# # Guia Funciones en Makecode

# %% [markdown]
# - Profesor: Alexander Acevedo Gómez
# - Ingeniero de sistemas
# - Msc Modelao y Simulación
# - @Alex6m

# %% [markdown]
# #### Obtención del sello

# %% [markdown]
# Escriba en su cuaderno:
# - Ambito: subprocesos o funciones
# - Competencia: 1
# - Objetivo: Aplicar correctamente los bloques de codigo en Makecode para definir e incocar una función que realice la tarea especifica.

# %% [markdown]
# 1. Copie el siguiente diagrama en su cuaderno, realice la representacion de los bloques de makecode lo mas precisos posible. (valor 5 pts)

# %% [markdown]
# [Link a diagrama](https://excalidraw.com/#json=dtaMFyqS8jXtX-rt2VXCJ,0ty1Be9anJB4gxU5qbuQkw)

# %% [markdown]
# 2. Ahora en Makecode configure los siguientes bloques para que su codigo se vea de la siguiente manera

# %% [markdown]
# [Link a bloques](https://excalidraw.com/#json=yPKLII28Oikb6ZQCw_ofZ,_W3oQqvrrVSW0LvfdX5SCQ)

# %% [markdown]
# 3. Conteste en su cuaderno (5 puntos)

# %% [markdown]
# > IMPORTANTE: __Cualquier intento de uso de IA anulará su actividad, sin perjuicio del proceso disciplinario a que hhubise lugar__

# %% [markdown]
# > 1. En terminos generales que accion realiza este programa
# > 2. Explique que significa el numero que aparece al final
# > 3. Indique que hace la variable `resultado`.

# %% [markdown]
# 4. Finalmente replique el siguiente diagrama a DrawIO (5 puntos)

# %% [markdown]
# ![Enlace para drawIO](funcion_longitud.svg)

# %% [markdown]
# ![Enlace para drawIO](diagrama_funciones.png)
